# %%
import pandas as pd

# %%
arquivo = "kc_house_data.csv"

# %%
df = pd.read_csv(arquivo, header = 0)

# %%
# %matplotlib notebook

# %%
dataset = df["price"].hist(bins= 30, color = "red")
# Out:
# <img src="data:image/png;base64,..." width="640">
