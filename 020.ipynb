# %%
import pandas as pd

# %%
# %matplotlib notebook

# %%
arquivo = "kc_house_data.csv"

# %%
df = pd.read_csv(arquivo, header = 0)

# %%
df.plot(x = "bedrooms", y = "price", kind = "scatter", title = "Quartos x Preços")
# Out:
# <img src="data:image/png;base64,..." width="640">
